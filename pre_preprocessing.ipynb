# %% [markdown]
# # **Imports**

# %%
import gzip
import json
import pandas as pd
import pickle

# %% [markdown]
# # **Preprocess Restaurant Rating Data**

# %%
file_path = '/content/meta-Massachusetts.json.gz'

data = []
with gzip.open(file_path, 'rt', encoding='utf-8') as file:
    for line in file:
        try:
            # Load the JSON object from each line
            obj = json.loads(line)
            data.append(obj)
        except json.JSONDecodeError as e:
            # Handle JSON decoding errors
            print(f"Error decoding JSON: {e}")

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                          name  \
# 0  Grace Ryder Housing Center
# 1                Sowing Seeds
# 2                 TLC Kennels
# 3     Pine Hill Sand & Gravel
# 4                Workout Club
#
#                                              address  \
# 0   Grace Ryder Housing Center, Marshfield, MA 02050
# 1   Sowing Seeds, 974 Plain St, Marshfield, MA 02050
# 2     TLC Kennels, 729 Center St, Pembroke, MA 02359
# 3  Pine Hill Sand & Gravel, 498 Old Westport Rd, ...
# 4  Workout Club, Webster Square, Marshfield, MA 0...
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x89e4a1f2d39fb621:0xfe62e9b7266e6262        None  42.098673 -70.719751
# 1  0x89e4a103dd188585:0xfadc47938337579f        None  42.107184 -70.757536
# 2  0x89e49871023b3407:0xd93aabe6f7940a6b        None  42.032471 -70.820770
# 3   0x89e4fcdcfa2fdba5:0xb10b326e00a0fd0        None  41.626680 -71.022437
# 4   0x89e4a6c554aa0e59:0x45965ec598f57a3        None  42.089767 -70.708462
#
#                     category  avg_rating  num_of_reviews price  \
# 0    [Senior citizen center]         4.8               3  None
# 1  [Non-profit organization]         4.6               8  None
# 2                   [Kennel]         4.0               4  None
# 3   [Sand & gravel supplier]         5.0               2  None
# 4                      [Gym]         4.5               4  None
#
#                                                hours  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  [[Thursday, 5:30AM–1PM], [Friday, 5:30AM–1PM],...
#
#                                                 MISC  \
# 0  {'Accessibility': ['Wheelchair accessible entr...
# 1  {'Accessibility': ['Wheelchair accessible entr...
# 2                                               None
# 3                                               None
# 4  {'Accessibility': ['Wheelchair accessible entr...
#
#                              state  \
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4  Closes soon ⋅ 1PM ⋅ Reopens 4PM
#
#                                     relative_results  \
# 0  [0x89e4a6ce94008f83:0x48244c8afd7f8d76, 0x89e4...
# 1  [0x89e4a6d00319316d:0x5d22d9b17e568648, 0x89e4...
# 2  [0x89e4a1c4b9d12e9b:0xc13185ea1dbed01a, 0x89e4...
# 3  [0x89e4fd3555b4674f:0x6d70e26b40185165, 0x89e4...
# 4  [0x89e4a6d001adbf99:0xdeb84714d054a18c, 0x89e4...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
restaurant_data = df[df['category'].apply(lambda x: 'restaurant' in str(x).lower() if x is not None else False)]
# Drop the ones without address/ description/ MISC options
restaurant_data.dropna(subset=['address', 'description', 'MISC', 'hours'], inplace=True)
# Maintain uniform symbol for prices
restaurant_data['price'].replace('₩', '$',regex=True, inplace=True)
# Map prices from symbols to numbers
price_mapping = {None: 0, '$': 1, '$$': 2, '$$$': 3, '$$$$': 4}
restaurant_data['price'] = restaurant_data['price'].replace(price_mapping)
# Remove permanently closed ones
restaurant_data = restaurant_data[restaurant_data['state'] != 'Permanently closed']
# If there are no opening hours present, fill them with the State Massachussets
restaurant_data['state'].fillna('Massachussets', inplace=True)
restaurant_data
# Out:
# <ipython-input-3-6302853d5053>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurant_data.dropna(subset=['address', 'description', 'MISC', 'hours'], inplace=True)
# <ipython-input-3-6302853d5053>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   restaurant_data['price'].replace('₩', '$',regex=True, inplace=True)
# <ipython-input-3-6302853d5053>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurant_data['price'].replace('₩', '$',regex=True, inplace=True)
# <ipython-input-3-6302853d5053>:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   restaurant_data['price'] = restaurant_data['price'].replace(price_mapping)
# <ipython-input-3-6302853d5053>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurant_data['price'] = restaurant_data['price'].replace(price_mapping)
# <ipython-input-3-6302853d5053>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   restaurant_data['state'].fillna('Massachussets', inplace=True)
# <ipython-input-3-6302853d5053>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurant_data['state'].fillna('Massachussets', inplace=True)
#                                     name  \
# 252                     Honey Dew Donuts
# 876                     Honey Dew Donuts
# 1614                             Dunkin'
# 2610                             Dunkin'
# 2645                             Dunkin'
# ...                                  ...
# 92504                   Rocco's Pizzeria
# 92505                       Tasty Burger
# 92508                   Hong Kong Eatery
# 92511                    Clover Food Lab
# 92514  Martha's Vineyard Chowder Company
#
#                                                  address  \
# 252         Honey Dew Donuts, MA-118, Rehoboth, MA 02769
# 876         Honey Dew Donuts, MA-118, Rehoboth, MA 02769
# 1614   Dunkin', In Mobil Gas Station, 185 Park Ave, W...
# 2610   Dunkin', 1931 Dorchester Ave, Dorchester, MA 0...
# 2645   Dunkin', Logan Airport Logan Intl Airport, Gat...
# ...                                                  ...
# 92504  Rocco's Pizzeria, in the Tisbury Marketplace, ...
# 92505   Tasty Burger, 1301 Boylston St, Boston, MA 02215
# 92508  Hong Kong Eatery, 79 Harrison Ave, Boston, MA ...
# 92511  Clover Food Lab, 5 Cambridge Center, Cambridge...
# 92514  Martha's Vineyard Chowder Company, 9 Oak Bluff...
#
#                                      gmap_id  \
# 252    0x89e45e492eda50b1:0x666de2dcb5417546
# 876    0x89e45e492eda50b1:0x666de2dcb5417546
# 1614   0x89e407f99a47ba47:0x9387988afe7799c1
# 2610   0x89e37b86cff22fa5:0x9ec7d8b55a77706b
# 2645   0x89e371881e42c5a3:0x27fd1b9af0d87940
# ...                                      ...
# 92504  0x89e52894d8bbeba1:0x3154f8fc3bc21315
# 92505  0x89e379f5e3d9fe1b:0xa265a864b0f05b6a
# 92508  0x89e37a7828570e3d:0x65a59e5e04b797bf
# 92511  0x89e370af398b981b:0xfc69c09d337bc2e0
# 92514  0x89e5290944643609:0x6b5cbf7224fe52bc
#
#                                              description   latitude  \
# 252    Informal chain serving up coffee drinks, donut...  41.902888
# 876    Informal chain serving up coffee drinks, donut...  41.902888
# 1614   Long-running chain serving signature breakfast...  42.272809
# 2610   Long-running chain serving signature breakfast...  42.285003
# 2645   Long-running chain serving signature breakfast...  42.365359
# ...                                                  ...        ...
# 92504  Pizza by the pie or slice along with sandwiche...  41.452166
# 92505  Late-night Fenway branch of a local retro burg...  42.344762
# 92508  Standard Chinese fare, including BBQ'd pork & ...  42.350961
# 92511  The menu changes daily at this quick-serve spo...  42.362698
# 92514  Airy, casual hangout famed for its namesake so...  41.457841
#
#        longitude                                           category  \
# 252   -71.249229  [Donut shop, Cafe, Coffee shop, Dessert shop, ...
# 876   -71.249229  [Donut shop, Cafe, Coffee shop, Dessert shop, ...
# 1614  -71.813540  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 2610  -71.064857  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 2645  -71.014714  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# ...          ...                                                ...
# 92504 -70.598973                                 [Pizza restaurant]
# 92505 -71.098375  [Hamburger restaurant, American restaurant, Fa...
# 92508 -71.061531  [Cantonese restaurant, Asian restaurant, Noodl...
# 92511 -71.087728  [Fast food restaurant, Breakfast restaurant, C...
# 92514 -70.557289  [Seafood restaurant, American restaurant, Rest...
#
#        avg_rating  num_of_reviews  price  \
# 252           4.4              18      1
# 876           4.4              18      1
# 1614          3.4              14      1
# 2610          3.9              38      1
# 2645          2.7              16      1
# ...           ...             ...    ...
# 92504         4.6             144      2
# 92505         4.5            2713      1
# 92508         4.1             708      1
# 92511         4.4             778      1
# 92514         4.4             445      2
#
#                                                    hours  \
# 252    [[Wednesday, 6AM–8PM], [Thursday, 6AM–8PM], [F...
# 876    [[Wednesday, 6AM–8PM], [Thursday, 6AM–8PM], [F...
# 1614   [[Tuesday, 5AM–8PM], [Wednesday, 5AM–7PM], [Th...
# 2610   [[Saturday, 5AM–7PM], [Sunday, 6AM–6PM], [Mond...
# 2645   [[Saturday, 6AM–1PM], [Sunday, 6AM–1PM], [Mond...
# ...                                                  ...
# 92504  [[Friday, 11:30AM–8PM], [Saturday, 4–8PM], [Su...
# 92505  [[Friday, 11AM–12AM], [Saturday, 11AM–12AM], [...
# 92508  [[Friday, 11AM–8:30PM], [Saturday, 11AM–8:30PM...
# 92511  [[Friday, 7AM–8PM], [Saturday, 7AM–8PM], [Sund...
# 92514  [[Thursday, Closed], [Friday, Closed], [Saturd...
#
#                                                     MISC               state  \
# 252    {'Service options': ['In-store shopping', 'Tak...   Open ⋅ Closes 8PM
# 876    {'Service options': ['In-store shopping', 'Tak...   Open ⋅ Closes 8PM
# 1614   {'Service options': ['Delivery', 'Takeout', 'D...  Closed ⋅ Opens 5AM
# 2610   {'Service options': ['Delivery', 'Takeout', 'D...   Open ⋅ Closes 7PM
# 2645   {'Service options': ['Takeout', 'Delivery', 'D...   Open ⋅ Closes 1PM
# ...                                                  ...                 ...
# 92504  {'Service options': ['Outdoor seating', 'Takeo...       Massachussets
# 92505  {'Service options': ['Outdoor seating', 'Curbs...       Massachussets
# 92508  {'Service options': ['No-contact delivery', 'D...       Massachussets
# 92511  {'Service options': ['Curbside pickup', 'Deliv...       Massachussets
# 92514  {'Service options': ['Outdoor seating', 'Curbs...       Massachussets
#
#                                         relative_results  \
# 252    [0x89e45f29b389030b:0xac7a45b7231a16bb, 0x89e4...
# 876    [0x89e45f29b389030b:0xac7a45b7231a16bb, 0x89e4...
# 1614   [0x89e40426a7dafbf9:0x6c68b73cd0eca176, 0x89e4...
# 2610   [0x89e37b838314ce8d:0x59a32d5dea9e3899, 0x89e3...
# 2645   [0x89e3703cb3fd8465:0xf73f9799696e64a6, 0x89e3...
# ...                                                  ...
# 92504  [0x89e5289388f24cf1:0x88c91d0daa4e6ec0, 0x89e5...
# 92505  [0x89e37a19e56a4565:0xbb2aefc495e8c505, 0x89e3...
# 92508  [0x89e37a783f12a0b1:0x2f772b596594e285, 0x89e3...
# 92511  [0x89e370adc5c60ab7:0x4f154a255d379c99, 0x89e3...
# 92514            [0x89e52e9e67f513eb:0x88cd497e3d3b6053]
#
#                                                      url
# 252    https://www.google.com/maps/place//data=!4m2!3...
# 876    https://www.google.com/maps/place//data=!4m2!3...
# 1614   https://www.google.com/maps/place//data=!4m2!3...
# 2610   https://www.google.com/maps/place//data=!4m2!3...
# 2645   https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 92504  https://www.google.com/maps/place//data=!4m2!3...
# 92505  https://www.google.com/maps/place//data=!4m2!3...
# 92508  https://www.google.com/maps/place//data=!4m2!3...
# 92511  https://www.google.com/maps/place//data=!4m2!3...
# 92514  https://www.google.com/maps/place//data=!4m2!3...
#
# [7824 rows x 15 columns]

# %%
restaurant_data.shape
# Out:
# (7824, 15)

# %%
# Dropping duplicate entries
restaurant_data = restaurant_data.drop_duplicates(subset="gmap_id", keep="first").reset_index(drop=True)
restaurant_data.shape
# Out:
# (7823, 15)

# %% [markdown]
# # **Preprocess Review Data**

# %%
file_path = '/content/review-Massachusetts_10.json.gz'
gmap_values = set(restaurant_data['gmap_id'])
data_review = []

with gzip.open(file_path, 'rt', encoding='utf-8') as file:
    for line in file:
        try:
            obj_review = json.loads(line)
            if obj_review['gmap_id'] in gmap_values:
                data_review.append(obj_review)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")

df_review = pd.DataFrame(data_review)

# Display the first few rows of the DataFrame
df_review.head()
# Out:
#                  user_id             name           time  rating  \
# 0  108932598687147151209     Tc Pendarvis  1608699447441       5
# 1  109115279620765929977  Scotty Wilshire  1609634311474       3
# 2  117010150918910515361  Kaitlynn Clarke  1517844338810       5
# 3  114980144744098714236         Rusty Da  1577661883869       4
# 4  104265840298214603897  Joseph Marinaro  1543766300884       3
#
#                                                 text  pics  resp  \
# 0  Love the Sale Associates But The Machines I do...  None  None
# 1                              Good for a short stop  None  None
# 2  My favorite coffee place around. Friendly staf...  None  None
# 3       Nice pastry is Ward of the money coffee good  None  None
# 4  Great service , but to much money for 2 coffee...  None  None
#
#                                  gmap_id
# 0  0x89e45e492eda50b1:0x666de2dcb5417546
# 1  0x89e45e492eda50b1:0x666de2dcb5417546
# 2  0x89e45e492eda50b1:0x666de2dcb5417546
# 3  0x89e45e492eda50b1:0x666de2dcb5417546
# 4  0x89e45e492eda50b1:0x666de2dcb5417546

# %%
df_review = df_review[~df_review['text'].isin([None, 'None'])]
df_review = df_review[['gmap_id', 'text']]
df_review = df_review.groupby('gmap_id')['text'].apply(lambda x: ' '.join(x)).reset_index()
df_review.shape
# Out:
# (7702, 2)

# %% [markdown]
# # **Merge Restaurant Data and Reviews**

# %%
doc_df = pd.merge(restaurant_data, df_review, on='gmap_id', how='inner')

def concat_dict_values(d):
    if d is None:
        return ''
    return ', '.join([f"{' '.join(value)}" for key, value in d.items()])


doc_df['doc_information'] = doc_df['name'].fillna(' ')+' '+doc_df['description'].fillna(' ') + ' ' + doc_df['category'].apply(lambda x: ' '.join(x) if isinstance(x, list) else str(x)) + ' ' + doc_df['MISC'].apply(concat_dict_values) + doc_df['text'].fillna('')

doc_df
# Out:
#                                    name  \
# 0                      Honey Dew Donuts
# 1                               Dunkin'
# 2                               Dunkin'
# 3                                Subway
# 4                        Great Barbecue
# ...                                 ...
# 7697                   Rocco's Pizzeria
# 7698                       Tasty Burger
# 7699                   Hong Kong Eatery
# 7700                    Clover Food Lab
# 7701  Martha's Vineyard Chowder Company
#
#                                                 address  \
# 0          Honey Dew Donuts, MA-118, Rehoboth, MA 02769
# 1     Dunkin', 1931 Dorchester Ave, Dorchester, MA 0...
# 2     Dunkin', General Saints Campus, 1 Hospital Dr,...
# 3                Subway, 330 Main St, Holyoke, MA 01040
# 4        Great Barbecue, 15 Hudson St, Boston, MA 02111
# ...                                                 ...
# 7697  Rocco's Pizzeria, in the Tisbury Marketplace, ...
# 7698   Tasty Burger, 1301 Boylston St, Boston, MA 02215
# 7699  Hong Kong Eatery, 79 Harrison Ave, Boston, MA ...
# 7700  Clover Food Lab, 5 Cambridge Center, Cambridge...
# 7701  Martha's Vineyard Chowder Company, 9 Oak Bluff...
#
#                                     gmap_id  \
# 0     0x89e45e492eda50b1:0x666de2dcb5417546
# 1     0x89e37b86cff22fa5:0x9ec7d8b55a77706b
# 2     0x89e3a43b5cccd095:0xac005005b8232057
# 3     0x89e6dc2386a9c681:0xce5704692516ba47
# 4     0x89e37a784834f1b7:0x10b63ece55edd451
# ...                                     ...
# 7697  0x89e52894d8bbeba1:0x3154f8fc3bc21315
# 7698  0x89e379f5e3d9fe1b:0xa265a864b0f05b6a
# 7699  0x89e37a7828570e3d:0x65a59e5e04b797bf
# 7700  0x89e370af398b981b:0xfc69c09d337bc2e0
# 7701  0x89e5290944643609:0x6b5cbf7224fe52bc
#
#                                             description   latitude  longitude  \
# 0     Informal chain serving up coffee drinks, donut...  41.902888 -71.249229
# 1     Long-running chain serving signature breakfast...  42.285003 -71.064857
# 2     Long-running chain serving signature breakfast...  42.645806 -71.301246
# 3     Casual counter-serve chain for build-your-own ...  42.200072 -72.606007
# 4     Ducks hang in the window of this basement Chin...  42.350741 -71.060224
# ...                                                 ...        ...        ...
# 7697  Pizza by the pie or slice along with sandwiche...  41.452166 -70.598973
# 7698  Late-night Fenway branch of a local retro burg...  42.344762 -71.098375
# 7699  Standard Chinese fare, including BBQ'd pork & ...  42.350961 -71.061531
# 7700  The menu changes daily at this quick-serve spo...  42.362698 -71.087728
# 7701  Airy, casual hangout famed for its namesake so...  41.457841 -70.557289
#
#                                                category  avg_rating  \
# 0     [Donut shop, Cafe, Coffee shop, Dessert shop, ...         4.4
# 1     [Coffee shop, Bagel shop, Bakery, Breakfast re...         3.9
# 2     [Coffee shop, Bagel shop, Bakery, Breakfast re...         4.3
# 3     [Sandwich shop, Caterer, Fast food restaurant,...         3.8
# 4                                 [Barbecue restaurant]         4.3
# ...                                                 ...         ...
# 7697                                 [Pizza restaurant]         4.6
# 7698  [Hamburger restaurant, American restaurant, Fa...         4.5
# 7699  [Cantonese restaurant, Asian restaurant, Noodl...         4.1
# 7700  [Fast food restaurant, Breakfast restaurant, C...         4.4
# 7701  [Seafood restaurant, American restaurant, Rest...         4.4
#
#       num_of_reviews  price  \
# 0                 18      1
# 1                 38      1
# 2                 33      1
# 3                 38      1
# 4                 24      0
# ...              ...    ...
# 7697             144      2
# 7698            2713      1
# 7699             708      1
# 7700             778      1
# 7701             445      2
#
#                                                   hours  \
# 0     [[Wednesday, 6AM–8PM], [Thursday, 6AM–8PM], [F...
# 1     [[Saturday, 5AM–7PM], [Sunday, 6AM–6PM], [Mond...
# 2     [[Saturday, 5AM–4PM], [Sunday, 5AM–4PM], [Mond...
# 3     [[Saturday, 10AM–8PM], [Sunday, 10AM–8PM], [Mo...
# 4     [[Wednesday, 8AM–8PM], [Thursday, 8AM–8PM], [F...
# ...                                                 ...
# 7697  [[Friday, 11:30AM–8PM], [Saturday, 4–8PM], [Su...
# 7698  [[Friday, 11AM–12AM], [Saturday, 11AM–12AM], [...
# 7699  [[Friday, 11AM–8:30PM], [Saturday, 11AM–8:30PM...
# 7700  [[Friday, 7AM–8PM], [Saturday, 7AM–8PM], [Sund...
# 7701  [[Thursday, Closed], [Friday, Closed], [Saturd...
#
#                                                    MISC  \
# 0     {'Service options': ['In-store shopping', 'Tak...
# 1     {'Service options': ['Delivery', 'Takeout', 'D...
# 2     {'Service options': ['Delivery', 'Takeout', 'D...
# 3     {'Service options': ['Curbside pickup', 'Deliv...
# 4     {'Service options': ['Takeout', 'Dine-in', 'De...
# ...                                                 ...
# 7697  {'Service options': ['Outdoor seating', 'Takeo...
# 7698  {'Service options': ['Outdoor seating', 'Curbs...
# 7699  {'Service options': ['No-contact delivery', 'D...
# 7700  {'Service options': ['Curbside pickup', 'Deliv...
# 7701  {'Service options': ['Outdoor seating', 'Curbs...
#
#                        state  \
# 0          Open ⋅ Closes 8PM
# 1          Open ⋅ Closes 7PM
# 2          Open ⋅ Closes 4PM
# 3        Closed ⋅ Opens 10AM
# 4     Closed ⋅ Opens 8AM Thu
# ...                      ...
# 7697           Massachussets
# 7698           Massachussets
# 7699           Massachussets
# 7700           Massachussets
# 7701           Massachussets
#
#                                        relative_results  \
# 0     [0x89e45f29b389030b:0xac7a45b7231a16bb, 0x89e4...
# 1     [0x89e37b838314ce8d:0x59a32d5dea9e3899, 0x89e3...
# 2     [0x89e3a467f0c2b439:0xa8bce92b785f6a32, 0x89e3...
# 3     [0x89e6dc1f42e4c371:0xf4eebcb15be067f4, 0x89e6...
# 4     [0x89e37a785ec445d7:0x6fca53319c6d705a, 0x89e3...
# ...                                                 ...
# 7697  [0x89e5289388f24cf1:0x88c91d0daa4e6ec0, 0x89e5...
# 7698  [0x89e37a19e56a4565:0xbb2aefc495e8c505, 0x89e3...
# 7699  [0x89e37a783f12a0b1:0x2f772b596594e285, 0x89e3...
# 7700  [0x89e370adc5c60ab7:0x4f154a255d379c99, 0x89e3...
# 7701            [0x89e52e9e67f513eb:0x88cd497e3d3b6053]
#
#                                                     url  \
# 0     https://www.google.com/maps/place//data=!4m2!3...
# 1     https://www.google.com/maps/place//data=!4m2!3...
# 2     https://www.google.com/maps/place//data=!4m2!3...
# 3     https://www.google.com/maps/place//data=!4m2!3...
# 4     https://www.google.com/maps/place//data=!4m2!3...
# ...                                                 ...
# 7697  https://www.google.com/maps/place//data=!4m2!3...
# 7698  https://www.google.com/maps/place//data=!4m2!3...
# 7699  https://www.google.com/maps/place//data=!4m2!3...
# 7700  https://www.google.com/maps/place//data=!4m2!3...
# 7701  https://www.google.com/maps/place//data=!4m2!3...
#
#                                                    text  \
# 0     Love the Sale Associates But The Machines I do...
# 1     Pretty hit or miss Dunkin opposite the red lin...
# 2     Its good, of course you know what to expect,  ...
# 3     The best way to eat fresh and healthy 😋 I love...
# 4     Cheap and great food! Loved the char siu here....
# ...                                                 ...
# 7697  Get you some Rocco's!\n\nTheir pizza/food/cust...
# 7698  We stopped here for a quick bit along our trip...
# 7699  Their roasted ducks, chickens, and porks are v...
# 7700  Whenever I visit Cambridge from the UK, I alwa...
# 7701  The food was fine. I would go back for the cla...
#
#                                         doc_information
# 0     Honey Dew Donuts Informal chain serving up cof...
# 1     Dunkin' Long-running chain serving signature b...
# 2     Dunkin' Long-running chain serving signature b...
# 3     Subway Casual counter-serve chain for build-yo...
# 4     Great Barbecue Ducks hang in the window of thi...
# ...                                                 ...
# 7697  Rocco's Pizzeria Pizza by the pie or slice alo...
# 7698  Tasty Burger Late-night Fenway branch of a loc...
# 7699  Hong Kong Eatery Standard Chinese fare, includ...
# 7700  Clover Food Lab The menu changes daily at this...
# 7701  Martha's Vineyard Chowder Company Airy, casual...
#
# [7702 rows x 17 columns]

# %%
for column in doc_df.columns:
    null_count = doc_df[column].isna().sum()
    print(f"{column}: {null_count}")
# Out:
# name: 0
# address: 0
# gmap_id: 0
# description: 0
# latitude: 0
# longitude: 0
# category: 0
# avg_rating: 0
# num_of_reviews: 0
# price: 0
# hours: 0
# MISC: 0
# state: 0
# relative_results: 63
# url: 0
# text: 0
# doc_information: 0

# %%
with open('restaurent_docs_ma.pickle', 'wb') as f:
    pickle.dump(doc_df, f)

# %%
from google.colab import files
files.download('restaurent_docs_ma.pickle')

# %% [markdown]
# # **Retrieval in action**

# %%
! pip install rank-bm25
# Out:
# Collecting rank-bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rank-bm25) (1.26.4)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: rank-bm25
# Successfully installed rank-bm25-0.2.2

# %%
from rank_bm25 import BM25Okapi
from sklearn.preprocessing import MinMaxScaler

# Tokenization using basic split (can be replaced with advanced tokenizers)
documents = doc_df['doc_information'].to_list()
document_ids = [i for i in range(len(documents))]
tokenized_docs = [doc.lower().split(" ") for doc in documents]  # Lowercased for consistency

# Initialize BM25 and tokenize query
bm25 = BM25Okapi(tokenized_docs)

# BM25 Scores
query = "Chinese Restaurants".lower()
query_tokens = query.split(" ")
doc_scores = bm25.get_scores(query_tokens)

# Normalize BM25 Scores
scaler = MinMaxScaler()
normalized_doc_scores = scaler.fit_transform(doc_scores.reshape(-1, 1)).flatten()

# Normalize Avg Ratings (if they exist)
avg_ratings = doc_df['avg_rating'].fillna(0).to_numpy()  # Handle missing values
normalized_avg_ratings = scaler.fit_transform(avg_ratings.reshape(-1, 1)).flatten()

# Combine Scores (Weighted Sum)
weight_bm25 = 0.7
weight_rating = 0.3
combined_scores = (
    weight_bm25 * normalized_doc_scores + weight_rating * normalized_avg_ratings
)

# Combine Document IDs, Scores, and Ratings
doc_scores_with_ids = list(
    zip(document_ids, doc_scores, avg_ratings, combined_scores)
)

# Sort by Combined Score
sorted_docs_with_ids = sorted(doc_scores_with_ids, key=lambda x: -x[3])

# Extract the top 10 indices
ind = [i for i, _, _, _ in sorted_docs_with_ids[:10]]

# Retrieve corresponding rows from doc_df
top_docs = doc_df.loc[ind, :]

# Display results
top_docs
# Out:
#                           name  \
# 2619                 Min's Wok
# 4691       Great Wok Wellesley
# 6962                    Mu Lan
# 5030             Lotus Blossom
# 3323  Lee Chen Chinese Cuisine
# 5296           Sichuan Gourmet
# 2237    Sichuan Gourmet Sharon
# 3375       Cheng-Du Restaurant
# 4586          Peppercorn House
# 1429               CK Shanghai
#
#                                                 address  \
# 2619  Min's Wok, 582 W Boylston St, Worcester, MA 01606
# 4691  Great Wok Wellesley, 180 Worcester St, Wellesl...
# 6962          Mu Lan, 228 Broadway, Cambridge, MA 02139
# 5030  Lotus Blossom, 394 Boston Post Rd, Sudbury, MA...
# 3323  Lee Chen Chinese Cuisine, 230 Winthrop Ave, La...
# 5296  Sichuan Gourmet, 271 Worcester Rd, Framingham,...
# 2237  Sichuan Gourmet Sharon, 388 S Main St, Sharon,...
# 3375  Cheng-Du Restaurant, 249 N Main St, Mansfield,...
# 4586    Peppercorn House, 318 Main St, Woburn, MA 01801
# 1429  CK Shanghai, 15 Washington St, Wellesley, MA 0...
#
#                                     gmap_id  \
# 2619  0x89e407907f2c0ec3:0xade514e9f31bd611
# 4691  0x89e383d2374a02b5:0x62039de83ba6f097
# 6962  0x89e370ada76b8b6b:0x1f052f56a2e28ec2
# 5030  0x89e38f1a05d016e5:0x59e1e7412694887e
# 3323  0x89e307cac6a5bed9:0xc513907d7d69116f
# 5296  0x89e3888ad057c257:0x3341c2f6289b8d0b
# 2237  0x89e47d78ddc7f2f9:0x6558347983c7a85e
# 3375  0x89e4625db090ba8d:0xa225b355850ea7ef
# 4586  0x89e375a942fed05d:0xd864b8d957eae274
# 1429  0x89e383c17a985a6d:0x8b713649b1039c20
#
#                                             description   latitude  longitude  \
# 2619  Small, simple restaurant turning out an extens...  42.311310 -71.797590
# 4691  Modern Chinese eatery & bar offering Hunan, Si...  42.315372 -71.244962
# 6962  A large menu of veggie-friendly Taiwanese dish...  42.366346 -71.094302
# 5030  Chinese & Japanese staples, including sushi, a...  42.361494 -71.418851
# 3323  Upscale eatery whose Sichuan menu features spi...  42.684834 -71.139416
# 5296  Casual Chinese restaurant supplying spiced-to-...  42.298890 -71.405663
# 2237  Dan dan noodles & other Sichuan specialties at...  42.107472 -71.198817
# 3375  Easygoing eatery specializing in Sichuan- & Ma...  42.030005 -71.218208
# 4586  Family-owned eatery providing familiar Chinese...  42.478480 -71.151708
# 1429  Popular Chinese restaurant boasting a charming...  42.325323 -71.259950
#
#                                                category  avg_rating  \
# 2619                               [Chinese restaurant]         4.6
# 4691  [Chinese restaurant, Asian restaurant, Deliver...         4.5
# 6962  [Taiwanese restaurant, Asian restaurant, Chine...         4.5
# 5030                   [Chinese restaurant, Restaurant]         4.4
# 3323                               [Chinese restaurant]         4.4
# 5296  [Sichuan restaurant, Asian restaurant, Chinese...         4.4
# 2237  [Sichuan restaurant, Chinese restaurant, Resta...         4.3
# 3375                               [Sichuan restaurant]         4.3
# 4586  [Chinese restaurant, Japanese restaurant, Rest...         4.7
# 1429                   [Chinese restaurant, Restaurant]         4.3
#
#       num_of_reviews  price  \
# 2619             264      1
# 4691             166      2
# 6962             646      2
# 5030             318      2
# 3323             358      2
# 5296            1008      2
# 2237             206      2
# 3375             267      2
# 4586             378      2
# 1429             145      2
#
#                                                   hours  \
# 2619  [[Thursday, 11AM–10PM], [Friday, 11AM–11PM], [...
# 4691  [[Friday, 11:30AM–11PM], [Saturday, 11:30AM–11...
# 6962  [[Saturday, 11AM–9PM], [Sunday, 11AM–9PM], [Mo...
# 5030  [[Wednesday, 10:30AM–9:30PM], [Thursday, 10:30...
# 3323  [[Saturday, 11AM–9:30PM], [Sunday, 11AM–9PM], ...
# 5296  [[Monday, 11:30AM–8:30PM], [Tuesday, 11:30AM–8...
# 2237  [[Saturday, 11:30AM–9:30PM], [Sunday, 11:30AM–...
# 3375  [[Saturday, 12–11PM], [Sunday, 12–10PM], [Mond...
# 4586  [[Friday, 12–10:45PM], [Saturday, 12–10:45PM],...
# 1429  [[Friday, 11:30AM–9PM], [Saturday, 11:30AM–9PM...
#
#                                                    MISC  \
# 2619  {'Service options': ['Takeout', 'Delivery', 'D...
# 4691  {'Service options': ['No-contact delivery', 'D...
# 6962  {'Service options': ['Delivery', 'Takeout', 'D...
# 5030  {'Service options': ['Delivery', 'Takeout', 'D...
# 3323  {'Service options': ['Takeout', 'Delivery', 'D...
# 5296  {'Service options': ['Takeout', 'Delivery', 'D...
# 2237  {'Service options': ['Takeout'], 'Highlights':...
# 3375  {'Service options': ['Delivery', 'Takeout', 'D...
# 4586  {'From the business': ['Identifies as women-le...
# 1429  {'Service options': ['Takeout'], 'Health & saf...
#
#                                        state  \
# 2619                      Open ⋅ Closes 10PM
# 4691                  Closed ⋅ Opens 11:30AM
# 6962                           Massachussets
# 5030                  Closed ⋅ Opens 10:30AM
# 3323                    Open ⋅ Closes 9:30PM
# 5296                           Massachussets
# 2237                  Closed ⋅ Opens 11:30AM
# 3375                     Closed ⋅ Opens 12PM
# 4586  Closes soon ⋅ 10:45PM ⋅ Opens 12PM Sat
# 1429              Closed ⋅ Opens 11:30AM Sat
#
#                                        relative_results  \
# 2619  [0x89e407e05064db67:0xc65b74e4ebd23164, 0x89e4...
# 4691  [0x89e38150c442bc85:0x101db8f4e1433fee, 0x89e3...
# 6962  [0x89e377546fdb064d:0x33da3bdf6ebd5e0d, 0x89e3...
# 5030  [0x89e3860c33b612ff:0xb348bb092edc4c2e, 0x89e3...
# 3323  [0x89e30659baac334d:0x61c941d4bd61b525, 0x89e3...
# 5296  [0x89e388f60741960b:0xaa95640e78027b47, 0x89e3...
# 2237  [0x89e48768edc272c9:0x77861ebdb6ab466, 0x89e47...
# 3375  [0x89e4625e1f6a6229:0x378ecf7802440605, 0x89e4...
# 4586  [0x89e375a97055aae3:0x90e1985f715cb87b, 0x89e3...
# 1429  [0x89e38150c442bc85:0x101db8f4e1433fee, 0x89e3...
#
#                                                     url  \
# 2619  https://www.google.com/maps/place//data=!4m2!3...
# 4691  https://www.google.com/maps/place//data=!4m2!3...
# 6962  https://www.google.com/maps/place//data=!4m2!3...
# 5030  https://www.google.com/maps/place//data=!4m2!3...
# 3323  https://www.google.com/maps/place//data=!4m2!3...
# 5296  https://www.google.com/maps/place//data=!4m2!3...
# 2237  https://www.google.com/maps/place//data=!4m2!3...
# 3375  https://www.google.com/maps/place//data=!4m2!3...
# 4586  https://www.google.com/maps/place//data=!4m2!3...
# 1429  https://www.google.com/maps/place//data=!4m2!3...
#
#                                                    text  \
# 2619  Great food very clean n they r really polite I...
# 4691  Excellent service with minimal waiting.\nGreat...
# 6962  Amazing Taiwanese Cuisine. The chicken was ama...
# 5030  Such great food and maybe the best takeout set...
# 3323  My party was given good service and served del...
# 5296  This place is easily one of the best ,in and a...
# 2237  I legit LOVE this place you guys. The food is ...
# 3375  CELIAC FRIENDLY\n\nI haven’t had anything remo...
# 4586  Best Asian cuisine I've EVER had! Every thing ...
# 1429  Awesome food selection and ambiance . Original...
#
#                                         doc_information
# 2619  Min's Wok Small, simple restaurant turning out...
# 4691  Great Wok Wellesley Modern Chinese eatery & ba...
# 6962  Mu Lan A large menu of veggie-friendly Taiwane...
# 5030  Lotus Blossom Chinese & Japanese staples, incl...
# 3323  Lee Chen Chinese Cuisine Upscale eatery whose ...
# 5296  Sichuan Gourmet Casual Chinese restaurant supp...
# 2237  Sichuan Gourmet Sharon Dan dan noodles & other...
# 3375  Cheng-Du Restaurant Easygoing eatery specializ...
# 4586  Peppercorn House Family-owned eatery providing...
# 1429  CK Shanghai Popular Chinese restaurant boastin...

# %%
from rank_bm25 import BM25Okapi
from sklearn.preprocessing import MinMaxScaler

#Restaurant document data
print("Loading Started")
data = pd.read_pickle('restaurent_docs_ma.pickle')
documents = data['doc_information'].to_list()
document_ids = [i for i in range(len(documents))]
tokenized_docs = [doc.lower().split(" ") for doc in documents]
bm25 = BM25Okapi(tokenized_docs)
print("Loading done")



# BM25 Scores
query = "Chinese"


query_tokens = query.split(" ")
# Get document scores
doc_scores = bm25.get_scores(query_tokens)
data['doc_scores'] = doc_scores

# latitude, longitude = get_lat_lon(zipcode)

# docs = get_documents_within_25miles(data,latitude,longitude)

# Normalize BM25 Scores
scaler = MinMaxScaler()
normalized_doc_scores = scaler.fit_transform(doc_scores.reshape(-1, 1)).flatten()

# Normalize Avg Ratings (if they exist)
avg_ratings = data['avg_rating'].fillna(0).to_numpy()  # Handle missing values
normalized_avg_ratings = scaler.fit_transform(avg_ratings.reshape(-1, 1)).flatten()

# Combine Scores (Weighted Sum)
weight_bm25 = 0.7
weight_rating = 0.3
combined_scores = (
    weight_bm25 * normalized_doc_scores + weight_rating * normalized_avg_ratings
)

# Combine Document IDs, Scores, and Ratings
doc_scores_with_ids = list(
    zip(document_ids, doc_scores, avg_ratings, combined_scores)
)

# Sort by Combined Score
sorted_docs_with_ids = sorted(doc_scores_with_ids, key=lambda x: -x[3])

# Extract the top 10 indices
ind = [i for i, _, _, _ in sorted_docs_with_ids[:10]]

# Retrieve corresponding rows from doc_df
top_10_docs = data.loc[ind, :]

# sorted_docs = docs.sort_values(by=['doc_scores', 'avg_rating'], ascending=[False, False])
# print(sorted_docs)
# top_10_docs = sorted_docs.head(10)
top_10_docs.fillna(' ', inplace=True)
top_10_docs_list = top_10_docs.to_dict(orient='records')
search_info ={}
search_info['items'] = top_10_docs_list
print(search_info)
# Out:
# Loading Started
# Loading done
# {'items': [{'name': "Mo'Rockin Fusion", 'address': "Mo'Rockin Fusion, 100 Hanover St, Boston, MA 02108", 'gmap_id': '0x89e49b80770784c5:0xd41d713711e42bc1', 'description': 'Casual option in Boston Public Market for create-your-own bowls & pita wraps, plus salads & shakes.', 'latitude': 42.3620534, 'longitude': -71.05704399999999, 'category': ['Moroccan restaurant'], 'avg_rating': 5.0, 'num_of_reviews': 46, 'price': 2, 'hours': [['Tuesday', 'Closed'], ['Wednesday', '11AM–5PM'], ['Thursday', '11AM–5PM'], ['Friday', '11AM–5PM'], ['Saturday', '11AM–5PM'], ['Sunday', 'Closed'], ['Monday', 'Closed']], 'MISC': {'Service options': ['No-contact delivery', 'Delivery', 'Takeout', 'Dine-in'], 'Health & safety': ['Mask required', 'Staff wear masks', 'Staff get temperature checks', 'Staff required to disinfect surfaces between visits'], 'Popular for': ['Lunch', 'Dinner', 'Solo dining'], 'Offerings': ['Comfort food', 'Healthy options', 'Quick bite'], 'Amenities': ['Good for kids'], 'Atmosphere': ['Casual'], 'Payments': ['NFC mobile payments']}, 'state': 'Closed ⋅ Opens 11AM Wed', 'relative_results': ['0x89e315830281eb9b:0x5ec1a6407a5099f4', '0x89e47fd1975e0dd7:0xd5bb4764a7fb23e2', '0x89e377568b8fe2dd:0xf1b69012b9dc4f27'], 'url': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x89e49b80770784c5:0xd41d713711e42bc1?authuser=-1&hl=en&gl=us', 'text': "Extremely yummy food! I ordered the yellow rice bowl with the sweet lamb, corn, and pineapple BBQ sauce, added lettuce too. Very good! Food is amazing!\n\nI stopped by this spot on my way to work one day and was so happy with my bowl. Every burst of flavor made me so happy! I would highly recommend this spot to anyone looking for a meal packed with a tasty & spicy kick.\n\nI look forward to heading back soon! One of my favorite restaurants in my area. The decorations are outstanding and service was phenomenal. The food was great and had a good variety for all taste types. Everything is good and perfect. Nothing will be disappointing. I had a great time here. Will surely coming back here in the future. Highly recommended! A great addition to the Public Market. Delicious food, cooked slow but served fast. The service is also incredible and you can tell they really take pride in their food. This is going to become a regular lunch spot for me! Delicious beef tagine, friendly service and good sized portions. Definitely worth a visit if you're in the Public Market Absolutely delicious. I've only had it at the food truck so if that comes near you you need to get it. By far the best one that comes to MASCO Good Truck Friday in the summer. Good couscous\nFresh lamb Healthy and tasty. Saw these guys at the Food Truck Festival in Salem Massachusetts. They had by far the best food truck cuisine I've ever had! All the flavors were on point and my dish was perfectly spicey. Well worth my money and if i see this truck anywhere else in my travels i will not hesitate to be a repeat customer!!! Keep up the good work! I get SO EXCITED when this truck rolls into the Fenway area. The rice, tofu and white garlic sauce are meant to be together, and I could eat an entire bowl of just the roasted beet salad! Great food great atmosphere  generous portions everything tasted amazing I will come again", 'doc_information': "Mo'Rockin Fusion Casual option in Boston Public Market for create-your-own bowls & pita wraps, plus salads & shakes. Moroccan restaurant No-contact delivery Delivery Takeout Dine-in, Mask required Staff wear masks Staff get temperature checks Staff required to disinfect surfaces between visits, Lunch Dinner Solo dining, Comfort food Healthy options Quick bite, Good for kids, Casual, NFC mobile paymentsExtremely yummy food! I ordered the yellow rice bowl with the sweet lamb, corn, and pineapple BBQ sauce, added lettuce too. Very good! Food is amazing!\n\nI stopped by this spot on my way to work one day and was so happy with my bowl. Every burst of flavor made me so happy! I would highly recommend this spo ...
